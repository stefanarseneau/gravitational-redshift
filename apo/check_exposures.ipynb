# %%
import glob
import numpy as np

from astropy.io import fits
from astropy.table import Table

from astropy.coordinates import SkyCoord
import astropy.units as u

import matplotlib.pyplot as plt

# %%
wd = glob.glob('process_ms/*')

# %%
temp = fits.open(wd[0])

# %%
temp[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -64 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 2034
# NAXIS2  =                    3
# RA      = '3:25:10.66'
# DEC     = '-1:11:14.78'
# NAME    = 'WD0325-0111'

# %%
wl = temp[0].data[0]
fl = temp[0].data[1]
print(temp[0].data[2])
# Out:
# [3.35663960e+32 3.47172160e+32 3.34544321e+32 ... 1.93129788e+32
#  1.98102825e+32 1.90480731e+32]

# %%
plt.plot(wl, fl)
