# %%
from astropy.io import fits
hdul = fits.open('data/binaries/all_columns_catalog.fits.gz')

# %%
print(hdul[1].header)
# Out:
# XTENSION= 'BINTABLE'           / binary table extension                         BITPIX  =                    8 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                  980 / length of dimension 1                          NAXIS2  =              1817594 / length of dimension 2                          PCOUNT  =                    0 / number of group parameters                     GCOUNT  =                    1 / number of groups                               TFIELDS =                  217 / number of table fields                         TTYPE1  = 'solution_id1'                                                        TFORM1  = 'K       '                                                            TTYPE2  = 'solution_id2'                                                        TFORM2  = 'K       '                                                            TTYPE3  = 'source_id1'                
# ...
